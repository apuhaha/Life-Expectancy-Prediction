# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the dataset

# %%
data=pd.read_csv("D:/life_exp_data.csv")

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# ### Looking for null values

# %%
data.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# There are some null values in the dataset.

# %%
#Dropping the null values
data=data.dropna()

# %%
sns.heatmap(data.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Looking for dupicates

# %%
dup=data.duplicated().sum()
dup
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataset.

# %% [markdown]
# ### Looking for outliers

# %%
plt.figure(figsize=(25,8))
sns.boxplot(data=data,width=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are outliers in the population column, but we are going to drop the column.

# %%
plt.figure(figsize=(20,20))
corr=data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#Dropping unnecessary columns
data=data.drop(['Country','Status','Total expenditure','percentage expenditure','Year','Schooling','Population'],axis=1)

# %% [markdown]
# ### Univariate Analysis

# %%
data.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Life expectancy '}>,
#         <AxesSubplot:title={'center':'Adult Mortality'}>,
#         <AxesSubplot:title={'center':'infant deaths'}>,
#         <AxesSubplot:title={'center':'Alcohol'}>],
#        [<AxesSubplot:title={'center':'Hepatitis B'}>,
#         <AxesSubplot:title={'center':'Measles '}>,
#         <AxesSubplot:title={'center':' BMI '}>,
#         <AxesSubplot:title={'center':'under-five deaths '}>],
#        [<AxesSubplot:title={'center':'Polio'}>,
#         <AxesSubplot:title={'center':'Diphtheria '}>,
#         <AxesSubplot:title={'center':' HIV/AIDS'}>,
#         <AxesSubplot:title={'center':'GDP'}>],
#        [<AxesSubplot:title={'center':' thinness  1-19 years'}>,
#         <AxesSubplot:title={'center':' thinness 5-9 years'}>,
#         <AxesSubplot:title={'center':'Income composition of resources'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x = 'Adult Mortality', y = 'Life expectancy ',hue='Life expectancy ', data = data)
# Out:
# <AxesSubplot:xlabel='Adult Mortality', ylabel='Life expectancy '>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x = ' HIV/AIDS', y = 'Life expectancy ',hue='Life expectancy ', data = data)
# Out:
# <AxesSubplot:xlabel=' HIV/AIDS', ylabel='Life expectancy '>

# %%
plt.figure(figsize=(20,5))
sns.histplot(x=' thinness  1-19 years',y='Life expectancy ',data=data)
# Out:
# <AxesSubplot:xlabel=' thinness  1-19 years', ylabel='Life expectancy '>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x = ' BMI ', y = 'Life expectancy ',hue='Life expectancy ', data = data)
# Out:
# <AxesSubplot:xlabel=' BMI ', ylabel='Life expectancy '>

# %% [markdown]
# ### Splitting the dataset into dependent and independant variables

# %%
y = data['Life expectancy '].values
x = data.drop(['Life expectancy '], axis=1).values

# %% [markdown]
# ### Splitting the dataset into training and testing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 20)

# %% [markdown]
# ### Modeling

# %%
lin = LinearRegression()

# %%
# fitting the model to the train data
lin.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin.predict(x_test)

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import mean_squared_error, accuracy_score
print('R^2: {}'.format(lin.score(x_test, y_test)))
print('rmse: {}'.format(np.sqrt(mean_squared_error(y_pred, y_test))))
# Out:
# R^2: 0.8119782162957356
# rmse: 3.842019494223387
